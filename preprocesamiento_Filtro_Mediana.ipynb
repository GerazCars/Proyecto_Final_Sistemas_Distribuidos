# %%
import cv2
import os

# %%
# Carpeta original
input_dir = "/content/drive/MyDrive/Classroom/SISTEMAS DISTRIBUIDOS ENE-JUN2026/Proyecto_Final/flowers"

# %%
# Carpeta salida
output_dir = "/content/drive/MyDrive/Classroom/SISTEMAS DISTRIBUIDOS ENE-JUN2026/Proyecto_Final/flowers_preprocesadas_Filtro_Mediana"

# %%
# Tamaño requerido por la CNN
IMG_SIZE = (150, 150)

# CREAR CARPETA DE SALIDA
os.makedirs(output_dir, exist_ok=True)

# RECORRER TODAS LAS CLASES
for clase in os.listdir(input_dir):
    ruta_entrada = os.path.join(input_dir, clase)
    if not os.path.isdir(ruta_entrada):
        continue
    ruta_salida = os.path.join(output_dir, clase)
    os.makedirs(ruta_salida, exist_ok=True)
    print(f"Procesando {clase}...")

# RECORRER IMÁGENES
    for archivo in os.listdir(ruta_entrada):
        ruta_imagen = os.path.join(ruta_entrada,archivo)
        try:
            img = cv2.imread(ruta_imagen)
            if img is None:
                continue

# FILTRO DE MEDIANA
            img_filtrada = cv2.medianBlur(img,3)

# REDIMENSIONAR
            img_filtrada = cv2.resize(img_filtrada,IMG_SIZE)

# GUARDAR
            salida = os.path.join(ruta_salida,archivo)
            cv2.imwrite(salida,img_filtrada)
        except Exception as e:
            print(f"Error en {archivo}: {e}")

print("\nProceso terminado correctamente.")
print(f"Dataset guardado en: {output_dir}")
# Out:
# Procesando daisy...
# Procesando rose...
# Procesando tulip...
# Procesando sunflower...
# Procesando dandelion...
#
# Proceso terminado correctamente.
# Dataset guardado en: /content/drive/MyDrive/Classroom/SISTEMAS DISTRIBUIDOS ENE-JUN2026/Proyecto_Final/flowers_preprocesadas_Filtro_Mediana
